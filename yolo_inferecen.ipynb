# %%
import os
import shutil

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
print(torch.cuda.is_available())

from ultralytics import YOLO

np.random.seed(42)
# Out:
# True

# %%
DATA_PATH = "E:\\OU\\master\\rm\\pre_shot_sniper_detection\\data\\data_aug_bias_dessert.yaml"
model = YOLO("./runs/weights_normal/350_imgs/weights/best.pt")

# %%
results = model.predict(source="./data/Why the US Army SNIPER Course is so Hard.mp4", show=True)
results
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/10696) e:\OU\master\rm\pre_shot_sniper_detection\data\Why the US Army SNIPER Course is so Hard.mp4: 384x640 1 snipers, 95.4ms
# video 1/1 (2/10696) e:\OU\master\rm\pre_shot_sniper_detection\data\Why the US Army SNIPER Course is so Hard.mp4: 384x640 1 snipers, 7.0ms
# video 1/1 (3/10696) e:\OU\master\rm\pre_shot_sniper_detection\data\Why the US Army SNIPER Course is so Hard.mp4: 384x640 1 snipers, 6.9ms
# ...
